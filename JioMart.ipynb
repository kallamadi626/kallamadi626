# %% [markdown]
# <a href="https://colab.research.google.com/github/kallamadi626/kallamadi626/blob/main/JioMart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing Needed Data

# %%
import numpy as py
import pandas as pd
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# #Identification of URL

# %%
URL1 = 'https://www.jiomart.com/c/groceries/2'
URL2 = 'https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'

# %% [markdown]
# #Loading the wb page in memeory using requests libbrary

# %%
page = requests.get(URL1)

# %% [markdown]
# #Check the status  code of the page

# %%
page.status_code
# Out:
# 200

# %%
htmlCode = page.text
soup= BeautifulSoup(htmlCode)

# %% [markdown]
# #Extracting the HTML Code of the Webpage

# %%
htmlCode
# Out:
# '<!doctype html> <html lang="en-US"> <head> <title>JioMart - Best Online Grocery Store for Your Daily Needs</title> <meta charset="utf-8"> <meta name="robots" content="INDEX,FOLLOW"> <meta name="description" content="Buy Grocery Online for your daily necessities from a wide range of Fruits &amp; Vegetables, Daily &amp; Bakery, Beverages, Home Care, etc. Visit JioMart online grocery market." /> <meta name="keywords" content="" /> <meta name="viewport" content="width=device-width, height=device-height, initial-scale=1.0, maximum-scale=1.0, user-scalable=0"> <meta name="theme-color" content="#ffffff"/> <link rel="manifest" href="https://www.jiomart.com/manifest.json"> <link rel="icon" type="image/x-icon" href="https://www.jiomart.com/assets/ds2web/jds-icons/favicon.svg" /> <link rel="canonical" href="https://www.jiomart.com/c/groceries/2" /> <meta property="og:site_name" content="JioMart" /> <meta property="og:type" content="website" /> <meta property="og:title" content="JioMart - Best 
# ...

# %% [markdown]
# #wraping Needed Data

# %%
name=soup.find('div',attrs={'class':"plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"})
print(name.text)
name=name.text
x=name.strip()
print(x)
# Out:
#  Zeneme Gold-Plated Brass Golden Classic Paisley Shaped Textured Handcrafted Bangles For Women (Set Of 4 )
# Zeneme Gold-Plated Brass Golden Classic Paisley Shaped Textured Handcrafted Bangles For Women (Set Of 4 )

# %%
res_names=[]
names=soup.find_all('div', attrs={'class':"plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"})
for i in names:
  x=i.text
  x=x.strip()
  res_names.append(x)
  print(res_names)
  print(len(res_names))
# Out:
# ['Zeneme Gold-Plated Brass Golden Classic Paisley Shaped Textured Handcrafted Bangles For Women (Set Of 4 )']
# 1
# ['Zeneme Gold-Plated Brass Golden Classic Paisley Shaped Textured Handcrafted Bangles For Women (Set Of 4 )', 'Lucky Jewellery 18K Gold Plated Designer Gold color Traditional Ethnic Bangles set For Women For Women (261-J1BG-1720-4-28)']
# 2
# ['Zeneme Gold-Plated Brass Golden Classic Paisley Shaped Textured Handcrafted Bangles For Women (Set Of 4 )', 'Lucky Jewellery 18K Gold Plated Designer Gold color Traditional Ethnic Bangles set For Women For Women (261-J1BG-1720-4-28)', 'BR Ornaments Copper Anklet (Pack of 2)']
# 3
# ...

# %%
res_prices=[]
prices=soup.find('div',attrs={'class':'plp-card-details-container'})
print(details.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-91639eb0f8db> in <cell line: 3>()
#       1 res_prices=[]
#       2 prices=soup.find('div',attrs={'class':'plp-card-details-container'})
# ----> 3 print(details.text)
#
# NameError: name 'details' is not defined
